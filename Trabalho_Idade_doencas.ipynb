# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataCV = pd.read_csv('../Trabalho/dados/cause_of_deaths.csv')
dataCV.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
def transpose_table(table):
    return table.transpose()

# %%
data_g = dataCV.groupby(['Year']).sum()

df = pd.DataFrame(data_g)
transposed_df = transpose_table(df)

data_g_soma = transposed_df.sum(axis=1) 

#print(transposed_df)
data_g_soma.sort_values(0)
#com a função Transpose, ele lista as doenças por ano, assim podemos identificar a curva de aumento ou diminuição de cada doença
# Out:
# C:\Users\Arthur Koch\AppData\Local\Temp\ipykernel_4124\2743718121.py:9: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   data_g_soma.sort_values(0)
# Exposure to Forces of Nature                    1490132
# Environmental Heat and Cold Exposure            1788851
# Poisonings                                      2601082
# Drug Use Disorders                              2656121
# Conflict and Terrorism                          3294053
# Fire, Heat, and Hot Substances                  3602914
# Acute Hepatitis                                 3784791
# Alcohol Use Disorders                           4819018
# Parkinson's Disease                             7179795
# Maternal Disorders                              7727046
# Drowning                                       10301999
# Meningitis                                     10524572
# Protein-Energy Malnutrition                    12031885
# ...

# %%
data_g = dataCV.groupby(['Year']).sum()
data_g = data_g.reset_index()
#data_g = data_g.reset_index()
data_g
#data_g.sum(axis=1) 
#Relação do aumento de causas por ano
# Out:
#     Year  Meningitis  Alzheimer's Disease and Other Dementias  \
# 0   1990      432253                                   560616
# 1   1991      428621                                   583166
# 2   1992      426440                                   605894
# 3   1993      420836                                   629571
# 4   1994      413799                                   652176
# 5   1995      409826                                   674815
# 6   1996      417259                                   696665
# 7   1997      400893                                   717342
# 8   1998      393364                                   738768
# 9   1999      390136                                   761620
# 10  2000      385994                                   786615
# 11  2001      379912                                   814526
# 12  2002      372298                                   845695
# 13  2003      369171                                   877011
# ...

# %%
def max_value_and_column_name(table, row_index):
    max_value = table.iloc[row_index].max()
    max_column = table.columns[table.iloc[row_index].argmax()]
    first_column = table.iloc[row_index][table.columns[0]]
    #first_column = table.index[row_index]
    return first_column, max_column, max_value

# %%
lista=[]
ii = data_g.shape[0]
i = 0
while i < ii:
    a,b,c = max_value_and_column_name(data_g,i)
    lista.append([a, b,c])
    i += 1
lista

#Pega o principal problema por ano
# Out:
# [[1990, 'Cardiovascular Diseases', 12062179],
#  [1991, 'Cardiovascular Diseases', 12220282],
#  [1992, 'Cardiovascular Diseases', 12437979],
#  [1993, 'Cardiovascular Diseases', 12802108],
#  [1994, 'Cardiovascular Diseases', 13026289],
#  [1995, 'Cardiovascular Diseases', 13129252],
#  [1996, 'Cardiovascular Diseases', 13213565],
#  [1997, 'Cardiovascular Diseases', 13339902],
#  [1998, 'Cardiovascular Diseases', 13461489],
#  [1999, 'Cardiovascular Diseases', 13720763],
#  [2000, 'Cardiovascular Diseases', 13957078],
#  [2001, 'Cardiovascular Diseases', 14185571],
#  [2002, 'Cardiovascular Diseases', 14501696],
#  [2003, 'Cardiovascular Diseases', 14710723],
#  [2004, 'Cardiovascular Diseases', 14745985],
#  [2005, 'Cardiovascular Diseases', 14995528],
#  [2006, 'Cardiovascular Diseases', 14991661],
#  [2007, 'Cardiovascular Diseases', 15117363],
#  [2008, 'Cardiovascular Diseases', 15402070],
#  [2009, 'Cardiovascular Diseases', 15552545],
# ...
